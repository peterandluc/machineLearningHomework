# %%
import findspark
findspark.init()
import pyspark
sc = pyspark.SparkContext()
sqlContext = pyspark.sql.SQLContext(sc)

# %%
import os

# %%
from sift.corpora import wikipedia, wikidata
from sift.models import text, links
wikipedia_base_path = 'data'
wikidata_base_path = '/n/schwa11/data0/linking/wikidata/dumps/20150713'

# %%
wikipedia_corpus = wikipedia.WikipediaCorpus()(sc, wikipedia_base_path)
docs = wikipedia.WikipediaArticles()(wikipedia_corpus).cache()

# %%
docs.take(1)
# Out:
# [{'_id': 'en.wikipedia.org/wiki/Anarchism',
#   'links': [{'start': 0,
#     'stop': 9,
#     'target': u'en.wikipedia.org/wiki/Anarchism'},
#    {'start': 15,
#     'stop': 35,
#     'target': u'en.wikipedia.org/wiki/Political_philosophy'},
#    {'start': 51,
#     'stop': 64,
#     'target': u'en.wikipedia.org/wiki/Self-governance'},
#    {'start': 137,
#     'stop': 156,
#     'target': u'en.wikipedia.org/wiki/Stateless_society'},
#    {'start': 248, 'stop': 260, 'target': u'en.wikipedia.org/wiki/Hierarchy'},
#    {'start': 264,
#     'stop': 281,
#     'target': u'en.wikipedia.org/wiki/Free_association_(communism_and_anarchism)'},
#    {'start': 303,
#     'stop': 308,
#     'target': u'en.wikipedia.org/wiki/State_(polity)'},
#    {'start': 360,
#     'stop': 383,
#     'target': u'en.wikipedia.org/wiki/Anti-statism'},
#    {'start': 548,
#     'stop': 556,
#     'target': u'en.wikipedia.org/wiki/Far-left_politics'},
#    {'start': 578,
#     'stop': 597,
#     'target': u'en.wikipedia.org/wiki/Anarchist_economics'},
#    {'start': 602,
#     'stop': 628,
#     'target': u'en.wikipedia.org/wiki/Anarchist_law'},
#    {'start': 638,
#     'stop': 672,
#     'target': u'en.wikipedia.org/wiki/Libertarian_socialism'},
#    {'start': 676,
#     'stop': 685,
#     'target': u'en.wikipedia.org/wiki/Anarcho-communism'},
#    {'start': 687,
#     'stop': 699,
#     'target': u'en.wikipedia.org/wiki/Collectivist_anarchism'},
#    {'start': 701,
#     'stop': 712,
#     'target': u'en.wikipedia.org/wiki/Anarcho-syndicalism'},
#    {'start': 714,
#     'stop': 723,
#     'target': u'en.wikipedia.org/wiki/Mutualism_(economic_theory)'},
#    {'start': 727,
#     'stop': 750,
#     'target': u'en.wikipedia.org/wiki/Participatory_economics'},
#    {'start': 972,
#     'stop': 1000,
#     'target': u'en.wikipedia.org/wiki/Anarchist_schools_of_thought'},
#    {'start': 1060,
#     'stop': 1073,
#     'target': u'en.wikipedia.org/wiki/Individualism'},
#    {'start': 1168,
#     'stop': 1174,
#     'target': u'en.wikipedia.org/wiki/Social_anarchism'},
#    {'start': 1179,
#     'stop': 1202,
#     'target': u'en.wikipedia.org/wiki/Individualist_anarchism'},
#    {'start': 1274,
#     'stop': 1283,
#     'target': u'en.wikipedia.org/wiki/Wikt:anarchism'},
#    {'start': 1312, 'stop': 1319, 'target': u'en.wikipedia.org/wiki/Anarchy'},
#    {'start': 1336, 'stop': 1340, 'target': u'en.wikipedia.org/wiki/-ism'},
#    {'start': 1465, 'stop': 1474, 'target': u'en.wikipedia.org/wiki/Privative'},
#    {'start': 1482,
#     'stop': 1484,
#     'target': u'en.wikipedia.org/wiki/Privative_alpha'},
#    {'start': 1556, 'stop': 1562, 'target': u'en.wikipedia.org/wiki/Archon'},
#    {'start': 1691,
#     'stop': 1701,
#     'target': u'en.wikipedia.org/wiki/Infinitive'},
#    {'start': 1802,
#     'stop': 1819,
#     'target': u'en.wikipedia.org/wiki/French_Revolution'},
#    {'start': 1857,
#     'stop': 1879,
#     'target': u'en.wikipedia.org/wiki/Maximilien_Robespierre'},
#    {'start': 1888,
#     'stop': 1898,
#     'target': u'en.wikipedia.org/wiki/H\xe9bertists'},
#    {'start': 2095,
#     'stop': 2109,
#     'target': u'en.wikipedia.org/wiki/William_Godwin'},
#    {'start': 2114,
#     'stop': 2130,
#     'target': u'en.wikipedia.org/wiki/Wilhelm_Weitling'},
#    {'start': 2298,
#     'stop': 2320,
#     'target': u'en.wikipedia.org/wiki/Pierre-Joseph_Proudhon'},
#    {'start': 2442,
#     'stop': 2456,
#     'target': u'en.wikipedia.org/wiki/Libertarianism'},
#    {'start': 2798,
#     'stop': 2819,
#     'target': u'en.wikipedia.org/wiki/Libertarian_anarchism'},
#    {'start': 2855, 'stop': 2862, 'target': u'en.wikipedia.org/wiki/Diggers'},
#    {'start': 2875,
#     'stop': 2890,
#     'target': u'en.wikipedia.org/wiki/William_Everard_(Digger)'},
#    {'start': 2977, 'stop': 2983, 'target': u'en.wikipedia.org/wiki/Taoism'},
#    {'start': 2996, 'stop': 3001, 'target': u'en.wikipedia.org/wiki/Laozi'},
#    {'start': 3028,
#     'stop': 3036,
#     'target': u'en.wikipedia.org/wiki/Zhuang_Zhou'},
#    {'start': 3183,
#     'stop': 3190,
#     'target': u'en.wikipedia.org/wiki/Wikt:brigand'},
#    {'start': 3221,
#     'stop': 3239,
#     'target': u'en.wikipedia.org/wiki/Diogenes_of_Sinope'},
#    {'start': 3248,
#     'stop': 3254,
#     'target': u'en.wikipedia.org/wiki/Cynicism_(philosophy)'},
#    {'start': 3286,
#     'stop': 3300,
#     'target': u'en.wikipedia.org/wiki/Zeno_of_Citium'},
#    {'start': 3317, 'stop': 3325, 'target': u'en.wikipedia.org/wiki/Stoicism'},
#    {'start': 3359, 'stop': 3364, 'target': u'en.wikipedia.org/wiki/Jesus'},
#    {'start': 3416,
#     'stop': 3435,
#     'target': u'en.wikipedia.org/wiki/Christian_anarchism'},
#    {'start': 3506, 'stop': 3511, 'target': u'en.wikipedia.org/wiki/Jesus'},
#    {'start': 3512,
#     'stop': 3518,
#     'target': u'en.wikipedia.org/wiki/Christ_(title)'},
#    {'start': 3571,
#     'stop': 3579,
#     'target': u'en.wikipedia.org/wiki/Apostle_(Christian)'},
#    {'start': 3591,
#     'stop': 3606,
#     'target': u'en.wikipedia.org/wiki/History_of_Islam'},
#    {'start': 3669,
#     'stop': 3686,
#     'target': u'en.wikipedia.org/wiki/Second_Fitna'},
#    {'start': 3696, 'stop': 3705, 'target': u'en.wikipedia.org/wiki/Caliphate'},
#    {'start': 3717,
#     'stop': 3727,
#     'target': u'en.wikipedia.org/wiki/Kharijites'},
#    {'start': 3746, 'stop': 3753, 'target': u'en.wikipedia.org/wiki/Imamate'},
#    {'start': 3825,
#     'stop': 3836,
#     'target': u'en.wikipedia.org/wiki/Renaissance_humanism'},
#    {'start': 3859,
#     'stop': 3879,
#     'target': u'en.wikipedia.org/wiki/\xc9tienne_de_La_Bo\xe9tie'},
#    {'start': 4025,
#     'stop': 4045,
#     'target': u'en.wikipedia.org/wiki/Protestant_Christianity'},
#    {'start': 4046,
#     'stop': 4064,
#     'target': u'en.wikipedia.org/wiki/Gerrard_Winstanley'},
#    {'start': 4267,
#     'stop': 4284,
#     'target': u'en.wikipedia.org/wiki/English_Civil_War'},
#    {'start': 4291,
#     'stop': 4304,
#     'target': u'en.wikipedia.org/wiki/Pejorative'},
#    {'start': 4314, 'stop': 4323, 'target': u'en.wikipedia.org/wiki/Cavalier'},
#    {'start': 4338, 'stop': 4347, 'target': u'en.wikipedia.org/wiki/Roundhead'},
#    {'start': 4415,
#     'stop': 4422,
#     'target': u'en.wikipedia.org/wiki/Enrag\xe9s'},
#    {'start': 4476,
#     'stop': 4483,
#     'target': u'en.wikipedia.org/wiki/Jacobin_(politics)'},
#    {'start': 4546, 'stop': 4554, 'target': u'en.wikipedia.org/wiki/Oxymoron'},
#    {'start': 4734,
#     'stop': 4747,
#     'target': u'en.wikipedia.org/wiki/Age_of_Enlightenment'},
#    {'start': 4762,
#     'stop': 4783,
#     'target': u'en.wikipedia.org/wiki/Jean-Jacques_Rousseau'},
#    {'start': 5018,
#     'stop': 5033,
#     'target': u'en.wikipedia.org/wiki/Peter_Kropotkin'},
#    {'start': 5243,
#     'stop': 5255,
#     'target': u'en.wikipedia.org/wiki/Edmund_Burke'},
#    {'start': 5548,
#     'stop': 5565,
#     'target': u'en.wikipedia.org/wiki/Political_Justice'},
#    {'start': 6216,
#     'stop': 6231,
#     'target': u'en.wikipedia.org/wiki/Property_rights'},
#    {'start': 6792,
#     'stop': 6809,
#     'target': u'en.wikipedia.org/wiki/What_is_Property?'},
#    {'start': 6948,
#     'stop': 6965,
#     'target': u'en.wikipedia.org/wiki/Spontaneous_order'},
#    {'start': 7285,
#     'stop': 7302,
#     'target': u'en.wikipedia.org/wiki/Property_is_theft'},
#    {'start': 7915,
#     'stop': 7930,
#     'target': u'en.wikipedia.org/wiki/Joseph_D\xe9jacque'},
#    {'start': 8238,
#     'stop': 8249,
#     'target': u'en.wikipedia.org/wiki/Max_Stirner'},
#    {'start': 8271,
#     'stop': 8290,
#     'target': u'en.wikipedia.org/wiki/The_Ego_and_Its_Own'},
#    {'start': 8411,
#     'stop': 8426,
#     'target': u'en.wikipedia.org/wiki/1848_Revolution'},
#    {'start': 8436,
#     'stop': 8457,
#     'target': u'en.wikipedia.org/wiki/Anselme_Bellegarrigue'},
#    {'start': 8498,
#     'stop': 8520,
#     'target': u'en.wikipedia.org/wiki/Pierre_Joseph_Proudhon'},
#    {'start': 8577,
#     'stop': 8592,
#     'target': u'en.wikipedia.org/wiki/Mikhail_Bakunin'},
#    {'start': 8605, 'stop': 8612, 'target': u'en.wikipedia.org/wiki/Marxist'},
#    {'start': 8620,
#     'stop': 8651,
#     'target': u'en.wikipedia.org/wiki/Dictatorship_of_the_proletariat'},
#    {'start': 8832,
#     'stop': 8851,
#     'target': u'en.wikipedia.org/wiki/Revolutions_of_1848'},
#    {'start': 9325,
#     'stop': 9332,
#     'target': u'en.wikipedia.org/wiki/Catalan_people'},
#    {'start': 9344,
#     'stop': 9365,
#     'target': u'en.wikipedia.org/wiki/Francesc_Pi_i_Margall'},
#    {'start': 9881,
#     'stop': 9904,
#     'target': u'en.wikipedia.org/wiki/Encyclop\xe6dia_Britannica'},
#    {'start': 9959,
#     'stop': 10033,
#     'target': u'en.wikipedia.org/wiki/Cantonal_Revolution'},
#    {'start': 10070,
#     'stop': 10108,
#     'target': u"en.wikipedia.org/wiki/International_Workingmen's_Association"},
#    {'start': 10232,
#     'stop': 10242,
#     'target': u'en.wikipedia.org/wiki/Blanquism'},
#    {'start': 10244,
#     'stop': 10256,
#     'target': u'en.wikipedia.org/wiki/Philadelphes'},
#    {'start': 10298,
#     'stop': 10314,
#     'target': u'en.wikipedia.org/wiki/Social_democrats'},
#    {'start': 10416,
#     'stop': 10425,
#     'target': u'en.wikipedia.org/wiki/Karl_Marx'},
#    {'start': 10561,
#     'stop': 10576,
#     'target': u'en.wikipedia.org/wiki/State_socialism'},
#    {'start': 10599,
#     'stop': 10612,
#     'target': u'en.wikipedia.org/wiki/Abstentionism'},
#    {'start': 10707,
#     'stop': 10723,
#     'target': u'en.wikipedia.org/wiki/Lysander_Spooner'},
#    {'start': 10728,
#     'stop': 10745,
#     'target': u'en.wikipedia.org/wiki/William_B._Greene'},
#    {'start': 10770,
#     'stop': 10789,
#     'target': u'en.wikipedia.org/wiki/First_International'},
#    {'start': 10850,
#     'stop': 10877,
#     'target': u'en.wikipedia.org/wiki/League_of_Peace_and_Freedom'},
#    {'start': 11082,
#     'stop': 11092,
#     'target': u'en.wikipedia.org/wiki/Federalist'},
#    {'start': 11478,
#     'stop': 11493,
#     'target': u'en.wikipedia.org/wiki/Mikhail_Bakunin'},
#    {'start': 11524,
#     'stop': 11534,
#     'target': u'en.wikipedia.org/wiki/Centralism'},
#    {'start': 11636,
#     'stop': 11648,
#     'target': u'en.wikipedia.org/wiki/Ruling_class'},
#    {'start': 12383,
#     'stop': 12397,
#     'target': u'en.wikipedia.org/wiki/Hague_Congress_(1872)'},
#    {'start': 12417,
#     'stop': 12432,
#     'target': u'en.wikipedia.org/wiki/James_Guillaume'},
#    {'start': 12596,
#     'stop': 12614,
#     'target': u'en.wikipedia.org/wiki/Anarchist_St._Imier_International'},
#    {'start': 12667,
#     'stop': 12680,
#     'target': u'en.wikipedia.org/wiki/Paris_Commune'},
#    {'start': 12979,
#     'stop': 12992,
#     'target': u'en.wikipedia.org/wiki/Louise_Michel'},
#    {'start': 13019,
#     'stop': 13032,
#     'target': u'en.wikipedia.org/wiki/Eugene_Varlin'},
#    {'start': 14115,
#     'stop': 14162,
#     'target': u'en.wikipedia.org/wiki/Federation_of_Organized_Trades_and_Labor_Unions'},
#    {'start': 14256,
#     'stop': 14275,
#     'target': u'en.wikipedia.org/wiki/Eight-hour_day'},
#    {'start': 14326,
#     'stop': 14338,
#     'target': u'en.wikipedia.org/wiki/Walter_Crane'},
#    {'start': 14389,
#     'stop': 14405,
#     'target': u'en.wikipedia.org/wiki/Haymarket_affair'},
#    {'start': 14588,
#     'stop': 14602,
#     'target': u'en.wikipedia.org/wiki/General_strike'},
#    {'start': 14673,
#     'stop': 14686,
#     'target': u'en.wikipedia.org/wiki/Strikebreaker'},
#    {'start': 15851,
#     'stop': 15877,
#     'target': u"en.wikipedia.org/wiki/International_Workers'_Day"},
#    {'start': 15971,
#     'stop': 16016,
#     'target': u'en.wikipedia.org/wiki/International_Anarchist_Congress_of_Amsterdam'},
#    {'start': 16137,
#     'stop': 16153,
#     'target': u'en.wikipedia.org/wiki/Errico_Malatesta'},
#    {'start': 16155,
#     'stop': 16169,
#     'target': u'en.wikipedia.org/wiki/Pierre_Monatte'},
#    {'start': 16171,
#     'stop': 16183,
#     'target': u'en.wikipedia.org/wiki/Luigi_Fabbri'},
#    {'start': 16185,
#     'stop': 16202,
#     'target': u'en.wikipedia.org/wiki/Beno\xeet_Broutchoux'},
#    {'start': 16204,
#     'stop': 16216,
#     'target': u'en.wikipedia.org/wiki/Emma_Goldman'},
#    {'start': 16218,
#     'stop': 16231,
#     'target': u'en.wikipedia.org/wiki/Rudolf_Rocker'},
#    {'start': 16237,
#     'stop': 16259,
#     'target': u'en.wikipedia.org/wiki/Christiaan_Cornelissen'},
#    {'start': 16379,
#     'stop': 16396,
#     'target': u'en.wikipedia.org/wiki/Popular_education'},
#    {'start': 16427,
#     'stop': 16441,
#     'target': u'en.wikipedia.org/wiki/Antimilitarism'},
#    {'start': 16505,
#     'stop': 16516,
#     'target': u'en.wikipedia.org/wiki/Syndicalism'},
#    {'start': 16521,
#     'stop': 16532,
#     'target': u'en.wikipedia.org/wiki/Trade_union'},
#    {'start': 16712,
#     'stop': 16729,
#     'target': u'en.wikipedia.org/wiki/Social_revolution'},
#    {'start': 16843,
#     'stop': 16852,
#     'target': u'en.wikipedia.org/wiki/Reformism'},
#    {'start': 16862,
#     'stop': 16874,
#     'target': u'en.wikipedia.org/wiki/Conservatism'},
#    {'start': 17202,
#     'stop': 17228,
#     'target': u'en.wikipedia.org/wiki/Federaci\xf3n_Anarquista_Ib\xe9rica'},
#    {'start': 17386,
#     'stop': 17420,
#     'target': u'en.wikipedia.org/wiki/Confederaci\xf3n_Nacional_del_Trabajo'},
#    {'start': 17637,
#     'stop': 17654,
#     'target': u'en.wikipedia.org/wiki/Spanish_Civil_War'},
#    {'start': 17688,
#     'stop': 17721,
#     'target': u'en.wikipedia.org/wiki/International_Workers_Association'},
#    {'start': 18088,
#     'stop': 18094,
#     'target': u'en.wikipedia.org/wiki/Anarchism_in_
#    {'start': 22028,
#     'stop': 22048,
#     'target': u'en.wikipedia.org/wiki/Carlos_I_of_Portugal'},
#    {'start': 22058,
#     'stop': 22076,
#     'target': u'en.wikipedia.org/wiki/George_I_of_Greece'},
#    {'start': 22098,
#     'stop': 22111,
#     'target': u'en.wikipedia.org/wiki/Leon_Czolgosz'},
#    {'start': 22161,
#     'stop': 22169,
#     'target': u'en.wikipedia.org/wiki/Feminist'},
#    {'start': 22238,
#     'stop': 22251,
#     'target': u'en.wikipedia.org/wiki/Nestor_Makhno'},
#    {'start': 22282,
#     'stop': 22327,
#     'target': u'en.wikipedia.org/wiki/Revolutionary_Insurrectionary_Army_of_Ukraine'},
#    {'start': 22367,
#     'stop': 22376,
#     'target': u'en.wikipedia.org/wiki/Bolshevik'},
#    {'start': 22386,
#     'stop': 22394,
#     'target': u'en.wikipedia.org/wiki/February_Revolution'},
#    {'start': 22399,
#     'stop': 22418,
#     'target': u'en.wikipedia.org/wiki/October_Revolution'},
#    {'start': 22633,
#     'stop': 22652,
#     'target': u'en.wikipedia.org/wiki/Kronstadt_rebellion'},
#    {'start': 22848, 'stop': 22855, 'target': u'en.wikipedia.org/wiki/Ukraine'},
#    {'start': 22871,
#     'stop': 22885,
#     'target': u'en.wikipedia.org/wiki/Free_Territory_(Ukraine)'},
#    {'start': 22906,
#     'stop': 22915,
#     'target': u'en.wikipedia.org/wiki/Russian_Civil_War'},
#    {'start': 22928,
#     'stop': 22934,
#     'target': u'en.wikipedia.org/wiki/White_movement'},
#    {'start': 23238,
#     'stop': 23255,
#     'target': u'en.wikipedia.org/wiki/Alexander_Berkman'},
#    {'start': 23897,
#     'stop': 23914,
#     'target': u'en.wikipedia.org/wiki/Communist_party'},
#    {'start': 24075,
#     'stop': 24078,
#     'target': u'en.wikipedia.org/wiki/Conf\xe9d\xe9ration_g\xe9n\xe9rale_du_travail'},
#    {'start': 24083,
#     'stop': 24086,
#     'target': u'en.wikipedia.org/wiki/Industrial_Workers_of_the_World'},
#    {'start': 24125,
#     'stop': 24148,
#     'target': u'en.wikipedia.org/wiki/Comintern'},
#    {'start': 24155,
#     'stop': 24184,
#     'target': u'en.wikipedia.org/wiki/Revolutions_of_1917\u201323'},
#    {'start': 24299,
#     'stop': 24329,
#     'target': u'en.wikipedia.org/wiki/German_Revolution_of_1918\u20131919'},
#    {'start': 24352,
#     'stop': 24376,
#     'target': u'en.wikipedia.org/wiki/Bavarian_Soviet_Republic'},
#    {'start': 24392,
#     'stop': 24407,
#     'target': u'en.wikipedia.org/wiki/Gustav_Landauer'},
#    {'start': 24409,
#     'stop': 24422,
#     'target': u'en.wikipedia.org/wiki/Silvio_Gesell'},
#    {'start': 24427,
#     'stop': 24439,
#     'target': u'en.wikipedia.org/wiki/Erich_M\xfchsam'},
#    {'start': 24500,
#     'stop': 24510,
#     'target': u'en.wikipedia.org/wiki/Council_communism'},
#    {'start': 24559,
#     'stop': 24572,
#     'target': u'en.wikipedia.org/wiki/Biennio_rosso'},
#    {'start': 24610,
#     'stop': 24635,
#     'target': u'en.wikipedia.org/wiki/Unione_Sindacale_Italiana'},
#    {'start': 24732,
#     'stop': 24744,
#     'target': u'en.wikipedia.org/wiki/Umanita_Nova'},
#    {'start': 24851,
#     'stop': 24869,
#     'target': u'en.wikipedia.org/wiki/Mexican_Revolution'},
#    {'start': 24874,
#     'stop': 24895,
#     'target': u'en.wikipedia.org/wiki/Mexican_Liberal_Party'},
#    {'start': 25052,
#     'stop': 25067,
#     'target': u'en.wikipedia.org/wiki/Baja_California'},
#    {'start': 25109,
#     'stop': 25129,
#     'target': u'en.wikipedia.org/wiki/Ricardo_Flores_Mag\xf3n'},
#    {'start': 25146,
#     'stop': 25157,
#     'target': u'en.wikipedia.org/wiki/Dielo_Truda'},
#    {'start': 25372,
#     'stop': 25438,
#     'target': u'en.wikipedia.org/wiki/Platformism'},
#    {'start': 25456,
#     'stop': 25467,
#     'target': u'en.wikipedia.org/wiki/Platformist'},
#    {'start': 25500,
#     'stop': 25527,
#     'target': u'en.wikipedia.org/wiki/Workers_Solidarity_Movement'},
#    {'start': 25547, 'stop': 25595, 'target': u'en.wikipedia.org/wiki/NEFAC'},
#    {'start': 25614,
#     'stop': 25633,
#     'target': u'en.wikipedia.org/wiki/Synthesis_anarchism'},
#    {'start': 25768,
#     'stop': 25796,
#     'target': u'en.wikipedia.org/wiki/Anarchism_without_adjectives'},
#    {'start': 25850, 'stop': 25855, 'target': u'en.wikipedia.org/wiki/Volin'},
#    {'start': 25860,
#     'stop': 25875,
#     'target': u'en.wikipedia.org/wiki/Sebastien_Faure'},
#    {'start': 25974,
#     'stop': 26012,
#     'target': u'en.wikipedia.org/wiki/International_of_Anarchist_Federations'},
#    {'start': 26224,
#     'stop': 26242,
#     'target': u'en.wikipedia.org/wiki/Anarchism_in_Italy'},
#    {'start': 26268,
#     'stop': 26280,
#     'target': u'en.wikipedia.org/wiki/Anti-fascism'},
#    {'start': 26295,
#     'stop': 26312,
#     'target': u'en.wikipedia.org/wiki/Arditi_del_Popolo'},
#    {'start': 26434,
#     'stop': 26445,
#     'target': u'en.wikipedia.org/wiki/Blackshirts'},
#    {'start': 26477, 'stop': 26482, 'target': u'en.wikipedia.org/wiki/Parma'},
#    {'start': 26672,
#     'stop': 26689,
#     'target': u'en.wikipedia.org/wiki/Far_right_leagues'},
#    {'start': 26724,
#     'stop': 26743,
#     'target': u'en.wikipedia.org/wiki/6_February_1934_crisis'},
#    {'start': 26771,
#     'stop': 26783,
#     'target': u'en.wikipedia.org/wiki/United_front'},
#    {'start': 26807,
#     'stop': 26813,
#     'target': u'en.wikipedia.org/wiki/Anarchism_in_France'},
#    {'start': 26843,
#     'stop': 26873,
#     'target': u'en.wikipedia.org/wiki/Resistance_during_World_War_II'},
#    {'start': 26900,
#     'stop': 26912,
#     'target': u'en.wikipedia.org/wiki/Erich_M\xfchsam'},
#    {'start': 27022,
#     'stop': 27036,
#     'target': u'en.wikipedia.org/wiki/Reichstag_fire'},
#    {'start': 27048,
#     'stop': 27063,
#     'target': u'en.wikipedia.org/wiki/Joseph_Goebbels'},
#    {'start': 27074,
#     'stop': 27093,
#     'target': u'en.wikipedia.org/wiki/Propagandaministerium'},
#    {'start': 27231,
#     'stop': 27241,
#     'target': u'en.wikipedia.org/wiki/Sonnenburg'},
#    {'start': 27268,
#     'stop': 27279,
#     'target': u'en.wikipedia.org/wiki/Oranienburg'},
#    {'start': 27331,
#     'stop': 27349,
#     'target': u'en.wikipedia.org/wiki/Nazi_concentration_camps'},
#    {'start': 27353,
#     'stop': 27364,
#     'target': u'en.wikipedia.org/wiki/Oranienburg_concentration_camp'},
#    {'start': 28089,
#     'stop': 28107,
#     'target': u'en.wikipedia.org/wiki/Anarchism_in_Spain'},
#    {'start': 28187,
#     'stop': 28196,
#     'target': u'en.wikipedia.org/wiki/Barcelona'},
#    {'start': 28242,
#     'stop': 28255,
#     'target': u'en.wikipedia.org/wiki/Collective_farming'},
#    {'start': 28375,
#     'stop': 28385,
#     'target': u'en.wikipedia.org/wiki/Stalinism'},
#    {'start': 28476,
#     'stop': 28488,
#     'target': u'en.wikipedia.org/wiki/Soviet_Union'},
#    {'start': 28503,
#     'stop': 28515,
#     'target': u'en.wikipedia.org/wiki/Noam_Chomsky'},
#    {'start': 29267,
#     'stop': 29288,
#     'target': u'en.wikipedia.org/wiki/Libertarian_socialist'},
#    {'start': 29392,
#     'stop': 29401,
#     'target': u'en.wikipedia.org/wiki/Catalonia'},
#    {'start': 29403,
#     'stop': 29409,
#     'target': u'en.wikipedia.org/wiki/Anarchist_Aragon'},
#    {'start': 29411,
#     'stop': 29420,
#     'target': u'en.wikipedia.org/wiki/Andalusia'},
#    {'start': 29435,
#     'stop': 29446,
#     'target': u'en.wikipedia.org/wiki/Levante,_Spain'},
#    {'start': 29456,
#     'stop': 29471,
#     'target': u"en.wikipedia.org/wiki/Spain's_economy"},
#    {'start': 29604,
#     'stop': 29628,
#     'target': u'en.wikipedia.org/wiki/Communist_Party_of_Spain_(main)'},
#    {'start': 29697,
#     'stop': 29713,
#     'target': u'en.wikipedia.org/wiki/Collectivisation'},
#    {'start': 29771,
#     'stop': 29779,
#     'target': u'en.wikipedia.org/wiki/Agriculture'},
#    {'start': 29830,
#     'stop': 29838,
#     'target': u'en.wikipedia.org/wiki/Commune_(intentional_community)'},
#    {'start': 29860,
#     'stop': 29871,
#     'target': u'en.wikipedia.org/wiki/Sam_Dolgoff'},
#    {'start': 30124,
#     'stop': 30147,
#     'target': u'en.wikipedia.org/wiki/Spanish_Communist_Party'},
#    {'start': 30206,
#     'stop': 30224,
#     'target': u"en.wikipedia.org/wiki/Workers'_Party_of_Marxist_Unification"},
#    {'start': 30273,
#     'stop': 30288,
#     'target': u'en.wikipedia.org/wiki/Camillo_Berneri'},
#    {'start': 30531,
#     'stop': 30555,
#     'target': u'en.wikipedia.org/wiki/Melchor_Rodr\xedguez_Garc\xeda'},
#    {'start': 30762,
#     'stop': 30790,
#     'target': u'en.wikipedia.org/wiki/Anarchism_in_Italy#Postwar_years_and_today'},
#    {'start': 30795,
#     'stop': 30801,
#     'target': u'en.wikipedia.org/wiki/Anarchism_in
#     'stop': 47842,
#     'target': u'en.wikipedia.org/wiki/Limited_government'},
#    {'start': 48124,
#     'stop': 48148,
#     'target': u'en.wikipedia.org/wiki/19th_century_philosophy'},
#    {'start': 48234,
#     'stop': 48250,
#     'target': u'en.wikipedia.org/wiki/Friedrich_Engels'},
#    {'start': 48321,
#     'stop': 48337,
#     'target': u'en.wikipedia.org/wiki/Egoist_anarchism'},
#    {'start': 48727,
#     'stop': 48733,
#     'target': u'en.wikipedia.org/wiki/Reification_(fallacy)'},
#    {'start': 48872,
#     'stop': 48889,
#     'target': u'en.wikipedia.org/wiki/Union_of_egoists'},
#    {'start': 49298,
#     'stop': 49308,
#     'target': u'en.wikipedia.org/wiki/Homosexual'},
#    {'start': 49318,
#     'stop': 49335,
#     'target': u'en.wikipedia.org/wiki/John_Henry_Mackay'},
#    {'start': 49338,
#     'stop': 49351,
#     'target': u'en.wikipedia.org/wiki/Josiah_Warren'},
#    {'start': 49799,
#     'stop': 49820,
#     'target': u'en.wikipedia.org/wiki/Stephen_Pearl_Andrews'},
#    {'start': 49922,
#     'stop': 49941,
#     'target': u'en.wikipedia.org/wiki/Henry_David_Thoreau'},
#    {'start': 50119,
#     'stop': 50137,
#     'target': u'en.wikipedia.org/wiki/Development_criticism'},
#    {'start': 50185,
#     'stop': 50202,
#     'target': u'en.wikipedia.org/wiki/Transcendentalist'},
#    {'start': 50236, 'stop': 50242, 'target': u'en.wikipedia.org/wiki/Walden'},
#    {'start': 50263,
#     'stop': 50276,
#     'target': u'en.wikipedia.org/wiki/Simple_living'},
#    {'start': 50318,
#     'stop': 50336,
#     'target': u'en.wikipedia.org/wiki/Civil_Disobedience_(Thoreau)'},
#    {'start': 50565,
#     'stop': 50572,
#     'target': u'en.wikipedia.org/wiki/Liberty_(1881\u20131908)'},
#    {'start': 50730,
#     'stop': 50739,
#     'target': u'en.wikipedia.org/wiki/Free_love'},
#    {'start': 50744,
#     'stop': 50757,
#     'target': u'en.wikipedia.org/wiki/Birth_control'},
#    {'start': 50773,
#     'stop': 50817,
#     'target': u'en.wikipedia.org/wiki/Anarchism_and_issues_related_to_love_and_sex'},
#    {'start': 50834,
#     'stop': 50843,
#     'target': u'en.wikipedia.org/wiki/Naturism'},
#    {'start': 50844, 'stop': 50851, 'target': u'en.wikipedia.org/wiki/Nudism'},
#    {'start': 50857,
#     'stop': 50873,
#     'target': u'en.wikipedia.org/wiki/Anarcho-naturism'},
#    {'start': 50876,
#     'stop': 50887,
#     'target': u'en.wikipedia.org/wiki/Freethought'},
#    {'start': 50892,
#     'stop': 50905,
#     'target': u'en.wikipedia.org/wiki/Anti-clericalism'},
#    {'start': 50990,
#     'stop': 51012,
#     'target': u'en.wikipedia.org/wiki/Individual_reclamation'},
#    {'start': 51018,
#     'stop': 51050,
#     'target': u'en.wikipedia.org/wiki/European_individualist_anarchism'},
#    {'start': 51055,
#     'stop': 51088,
#     'target': u'en.wikipedia.org/wiki/Individualist_anarchism_in_France'},
#    {'start': 51128,
#     'target': u'en.wikipedia.org/wiki/Heterosexual'},
#    {'start': 62026,
#     'stop': 62041,
#     'target': u'en.wikipedia.org/wiki/German_language'},
#    {'start': 62125,
#     'stop': 62140,
#     'target': u'en.wikipedia.org/wiki/Virginia_Bolten'},
#    {'start': 62610,
#     'stop': 62619,
#     'target': u'en.wikipedia.org/wiki/Polyamory'},
#    {'start': 62636, 'stop': 62643, 'target': u'en.wikipedia.org/wiki/Stirner'},
#    {'start': 62737,
#     'stop': 62748,
#     'target': u'en.wikipedia.org/wiki/Bisexuality'},
#    {'start': 62753,
#     'stop': 62766,
#     'target': u'en.wikipedia.org/wiki/Homosexuality'},
#    {'start': 62768,
#     'stop': 62782,
#     'target': u'en.wikipedia.org/wiki/Mujeres_Libres'},
#    {'start': 62899,
#     'stop': 62920,
#     'target': u'en.wikipedia.org/wiki/Luc\xeda_S\xe1nchez_Saornil'},
#    {'start': 62946,
#     'stop': 62966,
#     'target': u'en.wikipedia.org/wiki/Amparo_Poch_y_Gasc\xf3n'},
#    {'start': 63071,
#     'stop': 63089,
#     'target': u'en.wikipedia.org/wiki/Feminist_movement'},
#    {'start': 63337,
#     'stop': 63353,
#     'target': u'en.wikipedia.org/wiki/Anarcha-feminist'},
#    {'start': 63403, 'stop': 63410, 'target': u'en.wikipedia.org/wiki/Lesbian'},
#    {'start': 63604,
#     'stop': 63614,
#     'target': u'en.wikipedia.org/wiki/Censorship'},
#    {'start': 63659,
#     'stop': 63675,
#     'target': u'en.wikipedia.org/wiki/Anarcho-pacifist'},
#    {'start': 63717,
#     'stop': 63734,
#     'target': u'en.wikipedia.org/wiki/Sexual_revolution'},
#    {'start': 63774,
#     'stop': 63788,
#     'target': u'en.wikipedia.org/wiki/The_Joy_of_Sex'},
#    {'start': 63870,
#     'stop': 63878,
#     'target': u'en.wikipedia.org/wiki/Hedonist'},
#    {'start': 63891,
#     'stop': 63904,
#     'target': u'en.wikipedia.org/wiki/Michel_Onfray'},
#    {'start': 64088,
#     'stop': 64113,
#     'target': u'en.wikipedia.org/wiki/Francesc_Ferrer_i_Gu\xe0rdia'},
#    {'start': 64658,
#     'stop': 64675,
#     'target': u'en.wikipedia.org/wiki/Political_Justice'},
#    {'start': 64969,
#     'stop': 65005,
#     'target': u'en.wikipedia.org/wiki/The_False_Principle_of_our_Education'},
#    {'start': 65365,
#     'stop': 65379,
#     'target': u'en.wikipedia.org/wiki/Anti-Christianity'},
#    {'start': 65381,
#     'stop': 65394,
#     'target': u'en.wikipedia.org/wiki/Anti-clerical'},
#    {'start': 65835,
#     'stop': 65860,
#     'target': u'en.wikipedia.org/wiki/Lucifer,_the_Light-Bearer'},
#    {'start': 66238,
#     'stop': 66257,
#     'target': u'en.wikipedia.org/wiki/Progressive_education'},
#    {'start': 67077,
#     'stop': 67091,
#     'target': u'en.wikipedia.org/wiki/Modern_School_(United_States)'},
#    {'start': 67115, 'stop': 67119, 'target': u'en.wikipedia.org/wiki/Cuba'},
#    {'start': 67244,
#     'stop': 67263,
#     'target': u'en.wikipedia.org/wiki/Universit\xe0_popolare_(Italian_newspaper)'},
#    {'start': 67291,
#     'stop': 67310,
#     'target': u'en.wikipedia.org/wiki/Christian_anarchist'},
#    {'start': 68015,
#     'stop': 68026,
#     'target': u'en.wikipedia.org/wiki/Unschooling'},
#    {'start': 68035,
#     'stop': 68046,
#     'target': u'en.wikipedia.org/wiki/Anarchist_free_school'},
#    {'start': 68136,
#     'stop': 68147,
#     'target': u'en.wikipedia.org/wiki/A._S._Neill'},
#    {'start': 68169,
#     'stop': 68186,
#     'target': u'en.wikipedia.org/wiki/Summerhill_School'},
#    {'start': 68596,
#     'stop': 68607,
#     'target': u'en.wikipedia.org/wiki/Deschooling'},
#    {'start': 68627,
#     'stop': 68638,
#     'target': u'en.wikipedia.org/wiki/Ivan_Illich'},
#    {'start': 68920, 'stop': 68927, 'target': u'en.wikipedia.org/wiki/Utopian'},
#    {'start': 68956,
#     'stop': 68976,
#     'target': u'en.wikipedia.org/wiki/Category:Anarchism_by_country'},
#    {'start': 69009,
#     'stop': 69024,
#     'target': u'en.wikipedia.org/wiki/Harold_Barclay'},
#    {'start': 69231,
#     'stop': 69244,
#     'target': u'en.wikipedia.org/wiki/April_Carter'},
#    {'start': 69325,
#     'stop': 69392,
#     'target': u'libcom.org/library/caliban-witch-silvia-federici'},
#    {'start': 69457,
#     'stop': 69468,
#     'target': u'en.wikipedia.org/wiki/Pluto_Press'},
#    {'start': 69715,
#     'stop': 69731,
#     'target': u'en.wikipedia.org/wiki/Black_Rose_Books'},
#    {'start': 69850,
#     'stop': 69864,
#     'target': u'en.wikipedia.org/wiki/Daniel_Gu\xe9rin'},
#    {'start': 69866,
#     'stop': 69903,
#     'target': u'www.theanarchistlibrary.org/HTML/Daniel_Guerin__Anarchism__From_Theory_to_Practice.html'},
#    {'start': 69936,
#     'stop': 69952,
#     'target': u'en.wikipedia.org/wiki/Clifford_Harper'},
#    {'start': 70128,
#     'stop': 70144,
#     'target': u'en.wikipedia.org/wiki/The_Dispossessed'},
#    {'start': 70577,
#     'stop': 70589,
#     'target': u'en.wikipedia.org/wiki/Max_Nettlau'},
#    {'start': 70646,
#     'stop': 70661,
#     'target': u'en.wikipedia.org/wiki/James_C._Scott'},
#    {'start': 70664,
#     'stop': 70756,
#     'target': u'en.wikipedia.org/wiki/Two_Cheers_for_Anarchism:_Six_Easy_Pieces_on_Autonomy,_Dignity,_and_Meaningful_Work_and_Play'}],
#   'text': u'Anarchism is a political philosophy that advocates self-governed societies based on voluntary institutions. These are often described as stateless societies, although several authors have defined them more specifically as institutions based on non-hierarchical or free associations. Anarchism holds the state to be undesirable, unnecessary and harmful.\n\nWhile opposition to the state is central, anarchism specifically entails opposing authority or hierarchical organisation in the conduct of all human relations. Anarchism is usually considered a far-left ideology and much of anarchist economics and anarchist legal philosophy reflects anti-authoritarian interpretations of communism, collectivism, syndicalism, mutualism or participatory economics.\n\nAnarchism does not offer a fixed body of doctrine from a single particular world view, instead fluxing and flowing as a philosophy. Many types and traditions of anarchism exist, not all of which are mutually exclusive. Anarchist schools of thought can differ fundamentally, supporting anything from extreme individualism to complete collectivism. Strains of anarchism have often been divided into the categories of social and individualist anarchism or similar dual classifications.\n\nEtymology and terminology\n\nThe word "anarchism" is composed from the word "anarchy" and the suffix -ism, themselves derived respectively from the Greek , i.e. "anarchy" (from , "anarchos", meaning "one without rulers"; from the privative prefix \u1f00\u03bd- ("an-", i.e. "without") and , "archos", i.e. "leader", "ruler"; (cf. "archon" or , "arkh\u0113", i.e. "authority", "sovereignty", "realm", "magistracy")) and the suffix  or  ("-ismos", "-isma", from the verbal infinitive suffix -\u03af\u03b6\u03b5\u03b9\u03bd, "-izein"). The first known use of this word was in 1539. Various factions within the French Revolution labelled opponents as anarchists (as Maximilien Robespierre did the H\xe9bertists) although few shared many views of later anarchists. There would be many revolutionaries of the early nineteenth century who contributed to the anarchist doctrines of the next generation, such as William Godwin and Wilhelm Weitling, but they did not use the word "anarchist" or "anarchism" in describing themselves or their beliefs.\n\nThe first political philosopher to call himself an anarchist was Pierre-Joseph Proudhon, marking the formal birth of anarchism in the mid-nineteenth century. Since the 1890s and beginning in France, the term "libertarianism" has often been used as a synonym for anarchism and was used almost exclusively in this sense until the 1950s in the United States, though its use as a synonym is still common outside the United States. On the other hand, some use libertarianism to refer to individualistic free market philosophy only, referring to free market anarchism as libertarian anarchism.\n\nHistory\n\n\nOrigins\nWoodcut from a Diggers document by William Everard.\n\nThe earliest anarchist themes can be found in the 6th century BC among the works of Taoist philosopher Laozi and in later centuries by Zhuangzi and Bao Jingyan. Zhuangzi\'s philosophy has been described by various sources as anarchist. Zhuangzi wrote: "A petty thief is put in jail. A great brigand becomes a ruler of a Nation". Diogenes of Sinope and the Cynics, as well as their contemporary Zeno of Citium, the founder of Stoicism, also introduced similar topics. Jesus is sometimes considered the first anarchist in the Christian anarchist tradition. Georges Lechartier wrote: "The true founder of anarchy was Jesus Christ and\xa0... the first anarchist society was that of the apostles". In early Islamic history, some manifestations of anarchic thought are found during the Islamic civil war over the Caliphate, where the Kharijites insisted that the imamate is a right for each individual within the Islamic society.\n\nThe French renaissance political philosopher \xc9tienne de La Bo\xe9tie wrote in his most famous work the " ...

# %%
wikipedia_pfx = 'en.wikipedia.org/wiki/'

# %%
ec_model = links\
    .EntityCounts(min_count=5, filter_target=wikipedia_pfx)\
    .build(docs)\
    .map(links.EntityCounts.format_item)

# %%
enc_model = links\
    .EntityNameCounts(lowercase=True, filter_target=wikipedia_pfx)\
    .build(docs)\
    .filter(lambda (name, counts): sum(counts.itervalues()) > 1)\
    .map(links.EntityNameCounts.format_item)

# %%
ec_model.take(1)
# Out:
# [{'_id': u'en.wikipedia.org/wiki/Australian_federal_election,_1977',
#   'count': 15}]

# %%
enc_model.take(5)
# Out:
# [{'_id': u'biennials',
#   'counts': {u'en.wikipedia.org/wiki/Biennial_plant': 3},
#   'total': 3},
#  {'_id': u'seven-day weeks',
#   'counts': {u'en.wikipedia.org/wiki/Week': 2},
#   'total': 2},
#  {'_id': u'ernst gr\xfcnfeld',
#   'counts': {u'en.wikipedia.org/wiki/Ernst_Gr\xfcnfeld': 2},
#   'total': 2},
#  {'_id': u'down beat jazz hall of fame',
#   'counts': {u'en.wikipedia.org/wiki/Down_Beat': 1,
#    u'en.wikipedia.org/wiki/Down_Beat_Jazz_Hall_of_Fame': 1},
#   'total': 2},
#  {'_id': u'vani',
#   'counts': {u'en.wikipedia.org/wiki/Vani': 1,
#    u'en.wikipedia.org/wiki/Vani_Municipality': 1},
#   'total': 2}]

# %%
#start
from nel.model import data
from nel.model.store import file

# %%
os.environ['NEL_DATASTORE_URI'] = 'file:///data0/nel/'

# %%
# we can use model.toLocalIterator if models don't fit in memory

# %%
data.ObjectStore\
    .Get('models:ecounts[wikipedia]')\
    .save_many(ec_model.collect())
# Out:
# 2018-02-14 10:54:59,057|ERROR|data|Unsupported data store proto (/data), choose from (mongodb,redis,file)
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-30-df89e95aa460> in <module>()
# ----> 1 data.ObjectStore    .Get('models:ecounts[wikipedia]')    .save_many(ec_model.collect())
#
# /anaconda/envs/entity/lib/python2.7/site-packages/nel/model/data.pyc in Get(cls, store_id, **kwargs)
#      46         if store_cls == None:
#      47             log.error('Unsupported data store proto (%s), choose from (%s)', proto, ','.join(cls._impl_by_proto.iterkeys()))
# ---> 48             raise NotImplementedError
#      49
#      50         fmt_cls_name = re.sub('([A-Z])', r' \1', store_cls.__name__).strip().lower()
#
# NotImplementedError:

# %%
data.ObjectStore\
    .Get('models:necounts[wikipedia]')\
    .save_many(enc_model.collect())
# Out:
# 2018-02-14 10:55:40,093|ERROR|data|Unsupported data store proto (/data), choose from (mongodb,redis,file)
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-31-6c6e72ce6202> in <module>()
# ----> 1 data.ObjectStore    .Get('models:necounts[wikipedia]')    .save_many(enc_model.collect())
#
# /anaconda/envs/entity/lib/python2.7/site-packages/nel/model/data.pyc in Get(cls, store_id, **kwargs)
#      46         if store_cls == None:
#      47             log.error('Unsupported data store proto (%s), choose from (%s)', proto, ','.join(cls._impl_by_proto.iterkeys()))
# ---> 48             raise NotImplementedError
#      49
#      50         fmt_cls_name = re.sub('([A-Z])', r' \1', store_cls.__name__).strip().lower()
#
# NotImplementedError:

# %%
from nel.doc import Doc

# %%
from nel.harness.format import from_sift

# %%
from nel.process.pipeline import Pipeline
from nel.process.candidates import NameCounts
from nel.features.probability import EntityProbability, NameProbability

# %%
candidate_generation = [
    NameCounts('wikipedia', 10)
]
feature_extraction = [
    EntityProbability('wikipedia'),
    NameProbability('wikipedia')
]
# Out:
# 2018-02-13 11:15:33,333|INFO|candidates|Preparing name model candidate generator (model=wikipedia, limit=10)...
# 2018-02-13 11:15:33,335|DEBUG|data|Using file object store for (models:necounts[wikipedia])...
# 2018-02-13 11:15:33,337|WARNING|file|No existing mmap store found: /data0/nel/models/necounts[wikipedia].index ...
# 2018-02-13 11:15:33,339|DEBUG|data|Using file object store for (models:ecounts[wikipedia])...
# 2018-02-13 11:15:33,341|WARNING|file|No existing mmap store found: /data0/nel/models/ecounts[wikipedia].index ...
# 2018-02-13 11:15:33,343|DEBUG|data|Using file object store for (models:necounts[wikipedia])...
# 2018-02-13 11:15:33,345|WARNING|file|No existing mmap store found: /data0/nel/models/necounts[wikipedia].index ...

# %%
training_pipeline = Pipeline(candidate_generation + feature_extraction)

# %%
training_docs = [from_sift(doc) for doc in docs.takeSample(False, 100)]

# %%
train = [training_pipeline(doc) for doc in training_docs]

# %%
from nel.learn import ranking
from nel.features import meta
from nel.model import resolution
from nel.process import resolve

# %%
ranker = ranking.TrainLinearRanker(name='ranker', features=[f.id for f in feature_extraction])(train)
# Out:
# 2018-02-13 11:15:50,064|INFO|train|Computing feature statistics over 100 documents...
# /anaconda/envs/entity/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda/envs/entity/lib/python2.7/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /anaconda/envs/entity/lib/python2.7/site-packages/numpy/core/_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /anaconda/envs/entity/lib/python2.7/site-packages/numpy/core/_methods.py:105: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /anaconda/envs/entity/lib/python2.7/site-packages/numpy/core/_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 2018-02-13 11:15:50,225|INFO|train|Building training set, feature mapping = PolynomialMapper...
# 2018-02-13 11:15:50,283|INFO|train|Fitting model over 0 instances...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-a3b51ae6859d> in <module>()
# ----> 1 ranker = ranking.TrainLinearRanker(name='ranker', features=[f.id for f in feature_extraction])(train)
#
# /anaconda/envs/entity/lib/python2.7/site-packages/nel/learn/train.pyc in __call__(self, docs)
#      35         log.info('Fitting model over %i instances...', len(y))
#      36         classifier = self.init_model()
# ---> 37         classifier.fit(X, y)
#      38
#      39         correct = sum(1.0 for i, _y in enumerate(classifier.predict(X)) if y[i] == _y)
#
# /anaconda/envs/entity/lib/python2.7/site-packages/sklearn/svm/classes.pyc in fit(self, X, y, sample_weight)
#     225
#     226         X, y = check_X_y(X, y, accept_sparse='csr',
# --> 227                          dtype=np.float64, order="C")
#     228         check_classification_targets(y)
#     229         self.classes_ = np.unique(y)
#
# /anaconda/envs/entity/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /anaconda/envs/entity/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     439                     "Reshape your data either using array.reshape(-1, 1) if "
#     440                     "your data has a single feature or array.reshape(1, -1) "
# --> 441                     "if it contains a single sample.".format(array))
#     442             array = np.atleast_2d(array)
#     443             # To ensure that array flags are maintained
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
classifier_feature = meta.ClassifierScore(ranker)
linking = [
    classifier_feature,
    resolve.FeatureRankResolver(classifier_feature.id)
]

# %%
linking_pipeline = Pipeline(candidate_generation + feature_extraction + linking)

# %%
sample = [from_sift(doc) for doc in docs.takeSample(False, 10)]

# %%
# clear existing links
for doc in sample:
    for chain in doc.chains:
        chain.resolution = None
        for mention in chain.mentions:
            mention.resolution = None

# %%
linked_sample = [linking_pipeline(doc) for doc in sample]

# %%
[d.id for d in linked_sample]

# %%
sample[0].chains[0].resolution.id

# %%
from nel.harness.format import inject_markdown_links
from IPython.display import display, Markdown

# %%
display(Markdown(inject_markdown_links(linked_sample[0].text, linked_sample[0])))

# %%
from nel.process import tag, coref

mention_detection = [
    tag.SpacyTagger(),
    coref.SpanOverlap()
]

# %%
full_pipeline = Pipeline(mention_detection + candidate_generation + feature_extraction + linking)

# %%
linked_sample = [full_pipeline(doc) for doc in sample]

# %%
display(Markdown(inject_markdown_links(linked_sample[0].text, linked_sample[0], 'https://')))
